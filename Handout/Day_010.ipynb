# %%
import pandas as pd
iris = pd.read_csv('iris.csv')
iris
# Out:
#      sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal_width_in_cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %% [markdown]
# ## Data filter

# %%
# Search by condition 
iris[iris.sepal_length_in_cm < 4.5]
# Out:
#     sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 8                  4.4                2.9                 1.4
# 13                 4.3                3.0                 1.1
# 38                 4.4                3.0                 1.3
# 42                 4.4                3.2                 1.3
#
#     petal_width_in_cm        class
# 8                 0.2  Iris-setosa
# 13                0.1  Iris-setosa
# 38                0.2  Iris-setosa
# 42                0.2  Iris-setosa

# %%
# Search by condition 
iris.loc[iris.sepal_length_in_cm < 4.5]
# Out:
#     sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 8                  4.4                2.9                 1.4
# 13                 4.3                3.0                 1.1
# 38                 4.4                3.0                 1.3
# 42                 4.4                3.2                 1.3
#
#     petal_width_in_cm        class
# 8                 0.2  Iris-setosa
# 13                0.1  Iris-setosa
# 38                0.2  Iris-setosa
# 42                0.2  Iris-setosa

# %%
# Search by condition 
iris.loc[(iris.sepal_length_in_cm < 5) & (iris.sepal_width_in_cm < 3)]
# Out:
#      sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 8                   4.4                2.9                 1.4
# 41                  4.5                2.3                 1.3
# 57                  4.9                2.4                 3.3
# 106                 4.9                2.5                 4.5
#
#      petal_width_in_cm            class
# 8                  0.2      Iris-setosa
# 41                 0.3      Iris-setosa
# 57                 1.0  Iris-versicolor
# 106                1.7   Iris-virginica

# %%
# Search by index
iris.iloc[5:15, 2:]
# Out:
#     petal_length_in_cm  petal_width_in_cm        class
# 5                  1.7                0.4  Iris-setosa
# 6                  1.4                0.3  Iris-setosa
# 7                  1.5                0.2  Iris-setosa
# 8                  1.4                0.2  Iris-setosa
# 9                  1.5                0.1  Iris-setosa
# 10                 1.5                0.2  Iris-setosa
# 11                 1.6                0.2  Iris-setosa
# 12                 1.4                0.1  Iris-setosa
# 13                 1.1                0.1  Iris-setosa
# 14                 1.2                0.2  Iris-setosa

# %% [markdown]
# ## Combine Data

# %%
df_1 = pd.DataFrame([[1, 2, 3], [4, 5, 6]], index=[0, 1], columns=['A', 'B', 'C'])
df_2 = pd.DataFrame([[7, 8, 9], [0, 1, 2]], index=[0, 1], columns=['B', 'C', 'D'])
pd.concat([df_1, df_2], axis=0)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#      A  B  C    D
# 0  1.0  2  3  NaN
# 1  4.0  5  6  NaN
# 0  NaN  7  8  9.0
# 1  NaN  0  1  2.0

# %%
pd.concat([df_1, df_2], axis=1)
# Out:
#    A  B  C  B  C  D
# 0  1  2  3  7  8  9
# 1  4  5  6  0  1  2

# %%
pd.concat([df_1, df_2], axis=0, join='inner')
# Out:
#    B  C
# 0  2  3
# 1  5  6
# 0  7  8
# 1  0  1

# %%
pd.merge(df_1, df_2, on=['B', 'C'], how='outer')
# Out:
#      A  B  C    D
# 0  1.0  2  3  NaN
# 1  4.0  5  6  NaN
# 2  NaN  7  8  9.0
# 3  NaN  0  1  2.0

# %%
pd.merge(df_1, df_2, on=['B', 'C'], how='right')
# Out:
#     A  B  C  D
# 0 NaN  7  8  9
# 1 NaN  0  1  2

# %%
df_1_index = df_1.set_index(['B'])
df_2_index = df_2.set_index(['B'])
df_1_index.join(df_2_index, how='outer', lsuffix='_left', rsuffix='_right')
# Out:
#      A  C_left  C_right    D
# B
# 0  NaN     NaN      1.0  2.0
# 2  1.0     3.0      NaN  NaN
# 5  4.0     6.0      NaN  NaN
# 7  NaN     NaN      8.0  9.0

# %% [markdown]
# ## Get the data of row / column

# %%
df_3 = pd.DataFrame([[1, 2, 3], [4, 5, 6]], index=['a', 'b'], columns=['A', 'B', 'C'])
df_3
# Out:
#    A  B  C
# a  1  2  3
# b  4  5  6

# %%
# Search by name
df_3.loc[['a', 'b'],['B']]
# Out:
#    B
# a  2
# b  5

# %%
# Search by index
df_3.iloc[[0, 1], 1]
# Out:
# a    2
# b    5
# Name: B, dtype: int64

# %%
# Get certain value
print(df_3.at['a', 'B'])
print(df_3.iat[0, 1])
# Out:
# 2
# 2

# %% [markdown]
# ## Condition

# %%
print(df_3 > 4)
# Out:
#        A      B      C
# a  False  False  False
# b  False   True   True

# %%
df_3[df_3 > 4]
# Out:
#     A    B    C
# a NaN  NaN  NaN
# b NaN  5.0  6.0

# %%
df_3['B'][df_3['B'] >= 5]
# Out:
# b    5
# Name: B, dtype: int64
