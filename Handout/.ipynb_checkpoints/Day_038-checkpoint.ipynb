# %% [markdown]
# ## Fill null values with KNN method

# %%
import math
import sklearn
import statistics
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline

# %%
# Create a new data set
data = {'sex': ['Male','Male','Male','Male','Male','Female','Female','Female','Female','Female'],
        'age':[23,40,5,30,1,40,16,27,43,8],
        'height':[180,170,100,176,70,160,170,166,155,np.NAN],
        'weight':[100,68,20,np.NAN,10,np.NAN,50,58,58,17]}

data = pd.DataFrame(data)
display(data)
# Out:
#       sex  age  height  weight
# 0    Male   23   180.0   100.0
# 1    Male   40   170.0    68.0
# 2    Male    5   100.0    20.0
# 3    Male   30   176.0     NaN
# 4    Male    1    70.0    10.0
# 5  Female   40   160.0     NaN
# 6  Female   16   170.0    50.0
# 7  Female   27   166.0    58.0
# 8  Female   43   155.0    58.0
# 9  Female    8     NaN    17.0

# %%
# Check the missing values' rate
missing_vals = data.isnull().sum()/len(data)
missing_vals.sort_values(ascending=False)
missing_vals = pd.DataFrame(missing_vals, columns=['missing_rate'])
display(missing_vals)
# Out:
#         missing_rate
# sex              0.0
# age              0.0
# height           0.1
# weight           0.2

# %% [markdown]
# ## Observing data

# %%
# A significant height difference on sex
g = sns.catplot(x="sex", y="height", hue="sex", data=data, kind="box")

# %%
# The relationship between age and height
g = sns.regplot(x="age", y="height", color="g", data=data)

# %%
# The relationship between age and weight
g = sns.regplot(x="age", y="weight", color="g", data=data)

# %%
g = sns.catplot(x="sex", y='age', data=data, kind="box")

# %%
# Check the missing values
missing_index = data.isnull()
display(data[missing_index.values==True])
# Out:
#       sex  age  height  weight
# 3    Male   30   176.0     NaN
# 5  Female   40   160.0     NaN
# 9  Female    8     NaN    17.0

# %% [markdown]
# ## Transform the data

# %%
# Create a new data set
ori_data = {'sex': ['Male','Male','Male','Male','Male','Female','Female','Female','Female','Female'],
            'age':[23,40,5,30,1,40,16,27,43,8],
            'height':[180,170,100,176,70,160,170,166,155,np.NAN],
            'weight':[100,68,20,np.NAN,10,np.NAN,50,58,58,17]}

ori_data = pd.DataFrame(ori_data)
display(ori_data)
# Out:
#       sex  age  height  weight
# 0    Male   23   180.0   100.0
# 1    Male   40   170.0    68.0
# 2    Male    5   100.0    20.0
# 3    Male   30   176.0     NaN
# 4    Male    1    70.0    10.0
# 5  Female   40   160.0     NaN
# 6  Female   16   170.0    50.0
# 7  Female   27   166.0    58.0
# 8  Female   43   155.0    58.0
# 9  Female    8     NaN    17.0

# %%
from sklearn import preprocessing

# Transform sex to 0 and 1
data=ori_data.copy()
le = preprocessing.LabelEncoder()
data['sex'] = le.fit_transform(data['sex'])
display(data)
# Out:
#    sex  age  height  weight
# 0    1   23   180.0   100.0
# 1    1   40   170.0    68.0
# 2    1    5   100.0    20.0
# 3    1   30   176.0     NaN
# 4    1    1    70.0    10.0
# 5    0   40   160.0     NaN
# 6    0   16   170.0    50.0
# 7    0   27   166.0    58.0
# 8    0   43   155.0    58.0
# 9    0    8     NaN    17.0

# %%
from sklearn.metrics.pairwise import nan_euclidean_distances

# Calculate the distances between each dot
display(pd.DataFrame(nan_euclidean_distances(data)))
# Out:
#             0           1           2           3           4           5  \
# 0    0.000000   37.589892  114.560028    9.309493  143.819331   30.331502
# 1   37.589892    0.000000   91.809586   13.466007  122.004098   11.604597
# 2  114.560028   91.809586    0.000000   92.383260   31.874755   80.216374
# 3    9.309493   13.466007   92.383260    0.000000  126.896283   21.817424
# 4  143.819331  122.004098   31.874755  126.896283    0.000000  113.266647
# 5   30.331502   11.604597   80.216374   21.817424  113.266647    0.000000
# 6   51.478151   30.016662   76.954532   17.625739  108.747414   30.022214
# 7   44.463468   16.911535   79.277992   12.110601  110.440029   16.532796
# 8   52.820451   18.303005   76.902536   28.542366  106.273233    6.733003
# 9   97.399521   69.531767    5.033223   31.144823   11.489125   45.254834
#
#             6           7           8          9
# 0   51.478151   44.463468   52.820451  97.399521
# 1   30.016662   16.911535   18.303005  69.531767
# 2   76.954532   79.277992   76.902536   5.033223
# 3   17.625739   12.110601   28.542366  31.144823
# 4  108.747414  110.440029  106.273233  11.489125
# 5   30.022214   16.532796    6.733003  45.254834
# 6    0.000000   14.177447   31.906112  39.208843
# 7   14.177447    0.000000   19.416488  52.179178
# 8   31.906112   19.416488    0.000000  62.246821
# 9   39.208843   52.179178   62.246821   0.000000

# %%
from sklearn.impute import KNNImputer

# Fill the values
value_neighbors = 3
imputer = KNNImputer(n_neighbors=value_neighbors)
df_filled = pd.DataFrame(imputer.fit_transform(data))
display(df_filled)
# Out:
#      0     1           2           3
# 0  1.0  23.0  180.000000  100.000000
# 1  1.0  40.0  170.000000   68.000000
# 2  1.0   5.0  100.000000   20.000000
# 3  1.0  30.0  176.000000   75.333333
# 4  1.0   1.0   70.000000   10.000000
# 5  0.0  40.0  160.000000   61.333333
# 6  0.0  16.0  170.000000   50.000000
# 7  0.0  27.0  166.000000   58.000000
# 8  0.0  43.0  155.000000   58.000000
# 9  0.0   8.0  115.333333   17.000000

# %%
data=ori_data.copy()
le = preprocessing.LabelEncoder()
data['sex']=le.fit_transform(data['sex'])

# Weight = distance
value_neighbors=3
imputer = KNNImputer(n_neighbors=value_neighbors, weights='distance')
df_filled = pd.DataFrame(imputer.fit_transform(data))
display(df_filled)
# Out:
#      0     1           2           3
# 0  1.0  23.0  180.000000  100.000000
# 1  1.0  40.0  170.000000   68.000000
# 2  1.0   5.0  100.000000   20.000000
# 3  1.0  30.0  176.000000   77.883152
# 4  1.0   1.0   70.000000   10.000000
# 5  0.0  40.0  160.000000   60.919322
# 6  0.0  16.0  170.000000   50.000000
# 7  0.0  27.0  166.000000   58.000000
# 8  0.0  43.0  155.000000   58.000000
# 9  0.0   8.0   99.462122   17.000000

# %%
data=ori_data.copy()
le = preprocessing.LabelEncoder()
data['sex']=le.fit_transform(data['sex'])

# Weight = distance & add_indicato r= True
value_neighbors=3
imputer = KNNImputer(n_neighbors=value_neighbors, weights='distance', add_indicator=True)
df_filled = pd.DataFrame(imputer.fit_transform(data))
display(df_filled)
# Out:
#      0     1           2           3    4    5
# 0  1.0  23.0  180.000000  100.000000  0.0  0.0
# 1  1.0  40.0  170.000000   68.000000  0.0  0.0
# 2  1.0   5.0  100.000000   20.000000  0.0  0.0
# 3  1.0  30.0  176.000000   77.883152  0.0  1.0
# 4  1.0   1.0   70.000000   10.000000  0.0  0.0
# 5  0.0  40.0  160.000000   60.919322  0.0  1.0
# 6  0.0  16.0  170.000000   50.000000  0.0  0.0
# 7  0.0  27.0  166.000000   58.000000  0.0  0.0
# 8  0.0  43.0  155.000000   58.000000  0.0  0.0
# 9  0.0   8.0   99.462122   17.000000  1.0  0.0

# %%
# Fill the values with same sex
data=ori_data.copy() 
data['sex'].replace({'Male': 0,'Female': 1000},inplace=True)

value_neighbors = 5
imputer = KNNImputer(n_neighbors=value_neighbors)
df_filled = pd.DataFrame(imputer.fit_transform(data))
display(df_filled)
# Out:
#         0     1      2      3
# 0     0.0  23.0  180.0  100.0
# 1     0.0  40.0  170.0   68.0
# 2     0.0   5.0  100.0   20.0
# 3     0.0  30.0  176.0   51.2
# 4     0.0   1.0   70.0   10.0
# 5  1000.0  40.0  160.0   50.2
# 6  1000.0  16.0  170.0   50.0
# 7  1000.0  27.0  166.0   58.0
# 8  1000.0  43.0  155.0   58.0
# 9  1000.0   8.0  150.2   17.0

# %% [markdown]
# ## Mean-Square Error

# %%
data=ori_data.copy()
le = preprocessing.LabelEncoder()
data['sex']=le.fit_transform(data['sex'])

value_neighbors=3
imputer = KNNImputer(n_neighbors=value_neighbors, add_indicator=True)

# %%
import random

# Get the data set without null
completet_data = data.dropna()
completet_data = completet_data.reset_index(drop=True)
display(completet_data)
# Out:
#    sex  age  height  weight
# 0    1   23   180.0   100.0
# 1    1   40   170.0    68.0
# 2    1    5   100.0    20.0
# 3    1    1    70.0    10.0
# 4    0   16   170.0    50.0
# 5    0   27   166.0    58.0
# 6    0   43   155.0    58.0

# %%
# Get two random values as null values
a = random.sample(list(completet_data.index), 2) 
missing_data = completet_data.copy()
missing_data['height'].iloc[a] = np.nan
missing_data['weight'].iloc[a] = np.nan
display(missing_data)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#    sex  age  height  weight
# 0    1   23   180.0   100.0
# 1    1   40   170.0    68.0
# 2    1    5   100.0    20.0
# 3    1    1    70.0    10.0
# 4    0   16   170.0    50.0
# 5    0   27     NaN     NaN
# 6    0   43     NaN     NaN

# %%
# Fill the values with KNN method
verify_impute = pd.DataFrame(imputer.fit_transform(missing_data))
verify_impute.rename(columns={0:'sex',1:'age',2:'height',3:'weight',4:'imputed_h',5:'imputed_w'}, inplace=True)
display(verify_impute)
# Out:
#    sex   age      height      weight  imputed_h  imputed_w
# 0  1.0  23.0  180.000000  100.000000        0.0        0.0
# 1  1.0  40.0  170.000000   68.000000        0.0        0.0
# 2  1.0   5.0  100.000000   20.000000        0.0        0.0
# 3  1.0   1.0   70.000000   10.000000        0.0        0.0
# 4  0.0  16.0  170.000000   50.000000        0.0        0.0
# 5  0.0  27.0  173.333333   72.666667        1.0        1.0
# 6  0.0  43.0  173.333333   72.666667        1.0        1.0

# %%
from sklearn.metrics import mean_squared_error

# Complete the data
y_true1 = completet_data['height']
y_pred1 = verify_impute['height']
MSE_h=mean_squared_error(y_true1, y_pred1)
print('MSE_h:', MSE_h)

y_true1 =completet_data['weight']
y_pred1 = verify_impute['weight']
MSE_w = mean_squared_error(y_true1, y_pred1)
print('MSE_w:', MSE_w)
# Out:
# MSE_h: 55.69841269841277
# MSE_w: 61.460317460317505
