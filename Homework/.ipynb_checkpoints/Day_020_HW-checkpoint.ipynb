# %% [markdown]
# ## 1. 軸圖進階。

# %%
import matplotlib.pyplot as plt

# Background
plt.figure(facecolor='k')

# First window
plt.axes([0.1,0.1,.5,.5])
plt.xticks([]), plt.yticks([])
plt.text(0.1,0.1, 'axes([0.1,0.1,.5,.5])',ha='left',va='center',size=16,alpha=.5)

# Second window
plt.axes([0.3,0.3,.5,.5])
plt.text(0.1,0.1, 'axes([0.3,0.3,.5,.5])',ha='left',va='center',size=16,alpha=.5)

# Third window
plt.axes([0.5,0.5,.5,.5])
plt.text(0.1,0.1, 'axes([0.5,0.5,.5,.5])',ha='left',va='center',size=16,alpha=.5)

# Fourth window
plt.axes([0.7,0.7,.5,.5])
plt.text(0.1,0.1, 'axes([0.7,0.7,.5,.5])',ha='left',va='center',size=16,alpha=.5)

plt.show()

# %% [markdown]
# ## 2. 嘗試通過添加紅色條形標籤重現上側的圖形。

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 12 
X = np.arange(n)

Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)

# Upper section
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')

# Down section
plt.bar(X, -Y2, facecolor='r',alpha=.4, edgecolor='white')

# Set the segment
for x, y in zip(X,Y1):
    plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')
    
# Set y-axis segment
plt.ylim(-1.25,+1.25)
plt.show()
