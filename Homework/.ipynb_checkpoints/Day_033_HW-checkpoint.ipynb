# %% [markdown]
# ![sample%20mean%201.png](attachment:sample%20mean%201.png)

# %% [markdown]
# ## 1.   假設 x̄ > 2，拒絕 H0，α 會變大／變小？β 會變大／變小？

# %% [raw]
# Smaller / Bigger

# %% [markdown]
# ## 2.   假設 x̄ > 0.2，拒絕 Ho，會變大／變小？β 會變大/變小？

# %% [raw]
# Bigger / Smaller

# %% [markdown]
# ## 3. α 和 β 有關聯性？

# %% [raw]
# Inverse
