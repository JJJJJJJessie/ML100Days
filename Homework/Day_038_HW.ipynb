# %% [markdown]
# ## 1. 觀察 Age 和 Pclass 和 Sex 是否有關連性？

# %%
import math
import statistics
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from IPython.display import display

# %%
df_train = pd.read_csv("D:/Data Analysis/Python Data Science/ML100Days/Data/Titanic_train.csv")
df_train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Check the missing values' rate
missing_vals = df_train.isnull().sum()/len(df_train)
missing_vals.sort_values(ascending=False)
missing_vals = pd.DataFrame(missing_vals, columns=['missing_rate'])
display(missing_vals)
# Out:
#              missing_rate
# PassengerId      0.000000
# Survived         0.000000
# Pclass           0.000000
# Name             0.000000
# Sex              0.000000
# Age              0.198653
# SibSp            0.000000
# Parch            0.000000
# Ticket           0.000000
# Fare             0.000000
# Cabin            0.771044
# Embarked         0.002245

# %%
g = sns.FacetGrid(df_train, col='Pclass', hue='Sex')
g.map(sns.histplot, 'Age', edgecolor='white')
plt.legend()

# %%
g = sns.catplot(x="Pclass", y="Age", hue="Sex", data=df_train, kind="box")

# %% [markdown]
# ## 2. 運用 KNN ，取出 Age 、 Pclass、 Sex的資料，以 Sex 與 Pclass 補 Age 遺失值。

# %%
from sklearn import preprocessing

# Transform sex to 0 and 1
le = preprocessing.LabelEncoder()
df_train['Sex'] = le.fit_transform(df_train['Sex'])
display(df_train)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df_new = df_train[['Age', 'Pclass', 'Sex']]
df_new
# Out:
#       Age  Pclass  Sex
# 0    22.0       3    1
# 1    38.0       1    0
# 2    26.0       3    0
# 3    35.0       1    0
# 4    35.0       3    1
# ..    ...     ...  ...
# 886  27.0       2    1
# 887  19.0       1    0
# 888   NaN       3    0
# 889  26.0       1    1
# 890  32.0       3    1
#
# [891 rows x 3 columns]

# %%
from sklearn.metrics.pairwise import nan_euclidean_distances

# Calculate the distances between each dot
display(pd.DataFrame(nan_euclidean_distances(df_new)))
# Out:
#            0          1          2          3          4         5    \
# 0     0.000000  16.155494   4.123106  13.190906  13.000000  0.000000
# 1    16.155494   0.000000  12.165525   3.000000   3.741657  2.738613
# 2     4.123106  12.165525   0.000000   9.219544   9.055385  1.224745
# 3    13.190906   3.000000   9.219544   0.000000   2.236068  2.738613
# 4    13.000000   3.741657   9.055385   2.236068   0.000000  0.000000
# ..         ...        ...        ...        ...        ...       ...
# 886   5.099020  11.090537   1.732051   8.124038   8.062258  1.224745
# 887   3.741657  19.000000   7.280110  16.000000  16.155494  2.738613
# 888   1.224745   2.449490   0.000000   2.449490   1.224745  1.224745
# 889   4.472136  12.041595   2.236068   9.055385   9.219544  2.449490
# 890  10.000000   6.403124   6.082763   3.741657   3.000000  0.000000
#
#            6          7          8          9    ...        881        882  \
# ...

# %%
from sklearn.impute import KNNImputer

# Fill the values
value_neighbors = 3
imputer = KNNImputer(n_neighbors=value_neighbors, weights='distance')
df_filled = pd.DataFrame(imputer.fit_transform(df_new))
df_filled.rename(columns={0:'Age',1:'Pclass',2:'Sex'}, inplace=True)
display(df_filled)
# Out:
#       Age  Pclass  Sex
# 0    22.0     3.0  1.0
# 1    38.0     1.0  0.0
# 2    26.0     3.0  0.0
# 3    35.0     1.0  0.0
# 4    35.0     3.0  1.0
# ..    ...     ...  ...
# 886  27.0     2.0  1.0
# 887  19.0     1.0  0.0
# 888  19.0     3.0  0.0
# 889  26.0     1.0  1.0
# 890  32.0     3.0  1.0
#
# [891 rows x 3 columns]

# %%
# Check the missing values' rate
missing_vals = df_filled.isnull().sum()/len(df_filled)
missing_vals.sort_values(ascending=False)
missing_vals = pd.DataFrame(missing_vals, columns=['missing_rate'])
display(missing_vals)
# Out:
#         missing_rate
# Age              0.0
# Pclass           0.0
# Sex              0.0
